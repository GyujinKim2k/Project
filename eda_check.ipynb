# %%
import pandas as pd
import numpy as np
from pathlib import Path

# 1) Feather 로드 ----------------------------------------------------------
feat_path = Path("data/feature_store/daily_features.feather")
df = pd.read_feather(feat_path)

# %%
df[df['inventory_est']>0].describe()
# Out:
#                                 date       spot_id  total_rev_log1p  \
# count                        1642588  1.642588e+06     1.642588e+06
# mean   2024-02-19 06:35:50.126994432  2.284057e+03     5.210536e+00
# min              2023-01-06 00:00:00  1.000000e+00     0.000000e+00
# 25%              2023-09-13 00:00:00  1.626000e+03     0.000000e+00
# 50%              2024-03-10 00:00:00  2.127000e+03     0.000000e+00
# 75%              2024-08-12 00:00:00  3.408000e+03     1.092172e+01
# max              2024-12-31 00:00:00  4.390000e+03     1.434326e+01
# std                              NaN  1.101308e+03     5.465520e+00
#
#                 dow       week         month       quarter    is_weekend  \
# count  1.642588e+06  1642588.0  1.642588e+06  1.642588e+06  1.642588e+06
# mean   3.004015e+00  28.227708  6.934346e+00  2.639476e+00  2.871402e-01
# min    0.000000e+00        1.0  1.000000e+00  1.000000e+00  0.000000e+00
# ...

# %%
len(df[(df['total_rev_log1p']==0) & (df['inventory_est']>0)])
# Out:
# 855814

# %%
len(df['total_rev_log1p'])
# Out:
# 25712016

# %%
len(df[df['inventory_est']>0])
# Out:
# 1642588
